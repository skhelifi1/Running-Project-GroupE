# %%
#Setup--------------------------------------------

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

running_data= "Resources/2019boston_marathon_runners.csv"
running_data_df= pd.read_csv(running_data)
running_data_df.head()
# Out:
#   BibNumber          FullName           SortName AgeOnRaceDay Gender  \
# 0         2  Lawrence Cherono  Cherono, Lawrence           30      M
# 1         6     Lelisa Desisa     Desisa, Lelisa           29      M
# 2         7  Kenneth Kipkemoi  Kipkemoi, Kenneth           34      M
# 3         8      Felix Kandie      Kandie, Felix           32      M
# 4        11    Geoffrey Kirui    Kirui, Geoffrey           26      M
#
#        City StateAbbrev StateName  Zip CountryOfResAbbrev CountryOfResName  \
# 0   Eldoret         NaN       NaN  NaN                KEN            Kenya
# 1      Ambo         NaN       NaN  NaN                ETH         Ethiopia
# 2   Eldoret         NaN       NaN  NaN                KEN            Kenya
# 3      Iten         NaN       NaN  NaN                KEN            Kenya
# 4  Keringet         NaN       NaN  NaN                KEN            Kenya
#
#   CountryOfCtzAbbrev CountryOfCtzName OfficialTime RankOverall  \
# ...

# %%
#Clean up data for ages------------------------------

agetable = running_data_df.drop(['BibNumber',
                                'Gender',
                                'City',
                                'StateAbbrev',
                                'StateName',
                                'Zip',
                                'CountryOfResAbbrev',
                                'CountryOfResName',
                                'CountryOfCtzAbbrev',
                                'CountryOfCtzName',
                                'RankOverall',
                                'RankOverGender',
                                'RankOverDivision',
                                'EventGroup',
                                'SubGroupLabel',
                                'SubGroup',
                                'SortName'], axis=1)
agetable = agetable.set_index('FullName')
agetable
# Out:
#                    AgeOnRaceDay OfficialTime
# FullName
# Lawrence Cherono             30      2:07:57
# Lelisa Desisa                29      2:07:59
# Kenneth Kipkemoi             34      2:08:07
# Felix Kandie                 32      2:08:54
# Geoffrey Kirui               26      2:08:55
# ...                         ...          ...
# Denise Lewandowski           50      6:22:27
# Amanda Schmid                32      6:35:50
# Rhonda Foulds                55      6:53:38
# Candice Caesar               46      7:00:57
# Denise Smith                 51      7:25:39
#
# [26656 rows x 2 columns]

# %%
# Scatter plot based on age and performance

plt.scatter(agetable["AgeOnRaceDay"], agetable["OfficialTime"], marker='o', s=5, edgecolors= "blue")
plt.title("Age vs Performance")
plt.ylabel("Age")
plt.xlabel("Total Time")
#plt.grid()
plt.show()
plt.savefig('age_vs_performance.png')
